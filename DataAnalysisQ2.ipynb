# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import math

# %%
data4={'state':['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'], 'year':[2000,2001,2002,2001,2002,2003], 'pop':[1.5,1.7,3.6,2.4,2.9,3.2] }
print(data4)
# Out:
# {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'], 'year': [2000, 2001, 2002, 2001, 2002, 2003], 'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

# %%
frame=pd.DataFrame(data4)
print(frame)
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
data={'score':[0, 40, 7, 27, 0, 0, 0, 13, 0, 13, 7, 13, 0, 0, 7, 0, 0, 0, 13, 7, 13, 13]}
print(data)
# Out:
# {'score': [0, 40, 7, 27, 0, 0, 0, 13, 0, 13, 7, 13, 0, 0, 7, 0, 0, 0, 13, 7, 13, 13]}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#     score
# 0       0
# 1      40
# 2       7
# 3      27
# 4       0
# 5       0
# 6       0
# 7      13
# 8       0
# 9      13
# 10      7
# 11     13
# 12      0
# 13      0
# 14      7
# 15      0
# 16      0
# 17      0
# 18     13
# 19      7
# 20     13
# 21     13

# %%
np.mean(df)
# Out:
# score    7.863636
# dtype: float64

# %%
pd.DataFrame([df.mean(), df.std()], index=['Mean', 'Std. dev'])
# Out:
#               score
# Mean       7.863636
# Std. dev  10.185403

# %%
print(df.var())
# Out:
# score    103.742424
# dtype: float64

# %%
np.var(df)
# Out:
# score    99.02686
# dtype: float64

# %%
np.min(df)
# Out:
# score    0
# dtype: int64

# %%
np.max(df)
# Out:
# score    40
# dtype: int64

# %%
df.plot.hist(bins=10)

# %%
df.plot.hist(bins=10)
plt.xlim(0, 100)
# Out:
# (0, 100)

# %%
df.plot.density()

# %%
ax = df['score'].plot(kind='density')
mean_val = np.mean(ax.get_children()[0]._x)
# vertical dotted line originating at mean value
plt.axvline(mean_val, linestyle='dashed', linewidth=2)

# %%
ax = df['score'].plot(kind='density')
plt.xlim(0, 100)
mean_val = np.mean(ax.get_children()[0]._x)
# vertical dotted line originating at mean value
plt.axvline(mean_val, linestyle='dashed', linewidth=2)

# %%
mu = 7.86
variance = 10.1
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.show()
